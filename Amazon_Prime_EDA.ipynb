# %% [markdown]
# <a href="https://colab.research.google.com/github/Katla-Navyasree/Amazon-Prime-EDA/blob/main/Amazon_Prime_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - **Exploratory Data Analysis of Amazon Prime Videos Content Library**

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# ##### **Name**            - Katla Navyasree
# ##### **Batch**           - July 15th Batch

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# This project focuses on performing an Exploratory Data Analysis (EDA) on the Amazon Prime Video datasets, focusing on understanding the content catalog of TV shows and movies available on the platform. The analysis uncovers the patterns, trends and insights from the available data. The dataset includes various attributes such as movies and TV show titles, genres, release years, ratings and countries of origin.
#
# **Key Steps:**
# ##### This project involves:
# #####**Data Collection and Cleaning:** The project uses two datasets containing information about the titles and credits for movies and TV shows on Amazon Prime Video. The data was cleaned by handling missing values, removing duplicates, and ensuring data consistency.
# #####**Data Visualization:**
# #####**Insights:** The analysis revealed several key insights:
# *   Amazon Prime Video has more movies than TV shows. Drama and comedy are the most common genres.
# *   Movie runtimes have slightly decreased over the years, while TV shows have more seasons.
# *   Older titles tend to have higher ratings than newer releases.
# *   The United States is the primary content producer, followed by India and the United Kingdom.
#
# ##### This EDA provides valuable information for understanding the landscape of Amazon Prime Video's content. Content creators, platform strategists, and viewers can benefit from this analysis for making informed decisions. Future research could focus on specific genres, regions, or content types for deeper insights.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/Katla-Navyasree/Amazon-Prime-EDA.git

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# This dataset was created to analyze all shows available on Amazon Prime Video, allowing us to extract valuable insights such as:
#
# *   Content Diversity: What genres and categories dominate the platform?
# *   Regional Availability: How does content distribution vary across different regions?
# *   Trends Over Time: How has Amazon Prime's content library evolved?
# IMDb Ratings & Popularity: What are the highest-rated or most popular shows on the platform?
# *   By analyzing this dataset, businesses, content creators, and data analysts can uncover key trends that influence subscription growth, user engagement, and content investment strategies in the streaming industry.

# %% [markdown]
# ## **1. Know Your Data**

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
titles_df = pd.read_csv("/content/titles.csv")
credits_df = pd.read_csv("/content/credits.csv")

# %% [markdown]
# ### Dataset First View

# %%
# Dataset 1 (titles.csv) First Look
titles_df.columns
# Out:
# Index(['id', 'title', 'type', 'description', 'release_year',
#        'age_certification', 'runtime', 'genres', 'production_countries',
#        'seasons', 'imdb_id', 'imdb_score', 'imdb_votes', 'tmdb_popularity',
#        'tmdb_score'],
#       dtype='object')

# %%
# Dataset 1 (credits.csv) First Look
credits_df.columns
# Out:
# Index(['person_id', 'id', 'name', 'character', 'role'], dtype='object')

# %% [markdown]
# ## **2. Data Wrangling Code**

# %% [markdown]
# ### Merging Datasets

# %%
# merging the 2 datasets given on the common attribute 'id'
merged_data = pd.merge(titles_df, credits_df, on='id')
#printing the merged data
merged_data
# Out:
#                id              title   type  \
# 0         ts20945  The Three Stooges   SHOW
# 1         ts20945  The Three Stooges   SHOW
# 2         ts20945  The Three Stooges   SHOW
# 3         tm19248        The General  MOVIE
# 4         tm19248        The General  MOVIE
# ...           ...                ...    ...
# 124342  tm1054116           Baikunth  MOVIE
# 124343  tm1054116           Baikunth  MOVIE
# 124344  tm1054116           Baikunth  MOVIE
# 124345  tm1054116           Baikunth  MOVIE
# 124346  tm1054116           Baikunth  MOVIE
#
#                                               description  release_year  \
# 0       The Three Stooges were an American vaudeville ...          1934
# 1       The Three Stooges were an American vaudeville ...          1934
# 2       The Three Stooges were an American vaudeville ...          1934
# 3       During America’s Civil War, Union spies steal ...          1926
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
merged_data.shape
# Out:
# (124347, 19)

# %%
#fetching all the columns of the merged data
merged_data.columns
# Out:
# Index(['id', 'title', 'type', 'description', 'release_year',
#        'age_certification', 'runtime', 'genres', 'production_countries',
#        'seasons', 'imdb_id', 'imdb_score', 'imdb_votes', 'tmdb_popularity',
#        'tmdb_score', 'person_id', 'name', 'character', 'role'],
#       dtype='object')

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124347 entries, 0 to 124346
# Data columns (total 19 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    124347 non-null  object
#  1   title                 124347 non-null  object
#  2   type                  124347 non-null  object
#  3   description           124256 non-null  object
#  4   release_year          124347 non-null  int64
#  5   age_certification     56707 non-null   object
#  6   runtime               124347 non-null  int64
#  7   genres                124347 non-null  object
#  8   production_countries  124347 non-null  object
#  9   seasons               8153 non-null    float64
#  10  imdb_id               119044 non-null  object
#  11  imdb_score            118296 non-null  float64
#  12  imdb_votes            118272 non-null  float64
#  13  tmdb_popularity       124332 non-null  float64
# ...

# %% [markdown]
# ### **Dataset Description**
# The dataset is related to movies and TV shows available on Amazon Prime Video. It's formed by merging two datasets: titles.csv and credits.csv
# ##### **titles.csv** dataset contains information about the movies and TV shows available on Amazon Prime Video. Each row represents a single title.
# ##### **credits.csv** dataset contains information about the people invovled in the production of the titles like actors, directors, etc. Each row represents a person's involvement in a specific title.
#
#
# ---
#
#
# ### **Dataset has the following attributes:**
# ##### **id:** Unique identifier for each title (movie or TV show)
# ##### **title:** The Title of movie or TV show
# ##### **type:** Tells whether it's a 'SHOW' (TV show) or a 'MOVIE'
# ##### **description:** A brief description of the title
# ##### **release_year:** The year the title is released
# ##### **age_certification:** Age rating or certification (ex: PG-13, G, etc)
# ##### **runtime:** Duration of the Movie or TV Show in minutes
# ##### **genres:** List of genres associated with the titles
# ##### **production_countries:** List of countries where the title is produced
# ##### **seasons:** Number of seasons (for TV Shows)
# ##### **imdb_id:** IMDb identifier for the title
# ##### **imdb_score:** IMDb rating of the title
# ##### **imdb_votes:** Number of votes the title received on IMDb
# ##### **tmdb_popularity:** Popularity score from TMDb
# ##### **tmdb_score:** Rating score from TMDb
# ##### **person_id:** The person ID on JustWatch
# ##### **name:** The actor's or director's name
# ##### **character:** The character name played by the actor
# ##### **role:** The role of person in production (ex: 'ACTOR', 'DIRECTOR')

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Visualizing the missing values
merged_data.isnull().sum().plot(kind='bar')
# Out:
# <Axes: >

# %%
# Check for Null Values
merged_data.isnull().sum()
# Out:
# id                           0
# title                        0
# type                         0
# description                 91
# release_year                 0
# age_certification        67640
# runtime                      0
# genres                       0
# production_countries         0
# seasons                 116194
# imdb_id                   5303
# imdb_score                6051
# imdb_votes                6075
# tmdb_popularity             15
# tmdb_score               10265
# person_id                    0
# name                         0
# character                16307
# role                         0
# dtype: int64

# %% [markdown]
# Now lets drop all the null values in the respective columns

# %% [markdown]
# Let's drop all the null values in the descriptive column

# %%
#dropping null values from descriptive column
merged_data.dropna(subset=['description'], inplace=True)

# %%
#mode of age_certification
merged_data['age_certification'].mode()[0]
# Out:
# 'R'

# %%
#replacing all the null values of age_certification with mode
merged_data['age_certification'].fillna(merged_data['age_certification'].mode()[0], inplace=True)

# %%
merged_data.isnull().sum()
# Out:
# id                           0
# title                        0
# type                         0
# description                  0
# release_year                 0
# age_certification            0
# runtime                      0
# genres                       0
# production_countries         0
# seasons                 116155
# imdb_id                   5234
# imdb_score                5980
# imdb_votes                6004
# tmdb_popularity             13
# tmdb_score               10239
# person_id                    0
# name                         0
# character                16258
# role                         0
# dtype: int64

# %% [markdown]
# Now let's drop all the null values in the seasons column because it's only applicable to TV shows as movies dont have seasons so by default these entries would naturally be null. Instead of removing we will replace the null values with 0.

# %%
#replacing null values in season columns with 0
merged_data['seasons'].fillna(0, inplace=True)

# %%
merged_data.isnull().sum()
# Out:
# id                          0
# title                       0
# type                        0
# description                 0
# release_year                0
# age_certification           0
# runtime                     0
# genres                      0
# production_countries        0
# seasons                     0
# imdb_id                  5234
# imdb_score               5980
# imdb_votes               6004
# tmdb_popularity            13
# tmdb_score              10239
# person_id                   0
# name                        0
# character               16258
# role                        0
# dtype: int64

# %% [markdown]
# imdb_id is unique for Movies and TV shows, so we will drop all the null values in imdb_id column

# %%
#dropping the null values in imdb_id column
merged_data.dropna(subset=['imdb_id'], inplace=True)

# %%
merged_data.isnull().sum()
# Out:
# id                          0
# title                       0
# type                        0
# description                 0
# release_year                0
# age_certification           0
# runtime                     0
# genres                      0
# production_countries        0
# seasons                     0
# imdb_id                     0
# imdb_score                746
# imdb_votes                770
# tmdb_popularity            13
# tmdb_score               9118
# person_id                   0
# name                        0
# character               14989
# role                        0
# dtype: int64

# %% [markdown]
# imdb_score represents the rating of a Movie or TV Show, but removing the null values may lead to data loss so lets replace them with mean

# %%
round(merged_data['imdb_score'].mean(),1)
# Out:
# np.float64(6.0)

# %%
#replacing imdb_score null values with mean
merged_data['imdb_score'].fillna(merged_data['imdb_score'].mean(), inplace=True)

# %%
merged_data.shape
# Out:
# (119022, 19)

# %%
merged_data.isnull().sum()
# Out:
# id                          0
# title                       0
# type                        0
# description                 0
# release_year                0
# age_certification           0
# runtime                     0
# genres                      0
# production_countries        0
# seasons                     0
# imdb_id                     0
# imdb_score                  0
# imdb_votes                770
# tmdb_popularity            13
# tmdb_score               9118
# person_id                   0
# name                        0
# character               14989
# role                        0
# dtype: int64

# %% [markdown]
# imdb_votes represents the number of votes a Movie or TV Show has received. Missing values in imdb_votes may indicate that the movie is relatively new or has not gained much attention. It's better to replace the null values with 0.

# %%
#replacing null values of imdb_votes to 0
merged_data['imdb_votes'].fillna(0, inplace=True)

# %%
merged_data.isnull().sum()
# Out:
# id                          0
# title                       0
# type                        0
# description                 0
# release_year                0
# age_certification           0
# runtime                     0
# genres                      0
# production_countries        0
# seasons                     0
# imdb_id                     0
# imdb_score                  0
# imdb_votes                  0
# tmdb_popularity            13
# tmdb_score               9118
# person_id                   0
# name                        0
# character               14989
# role                        0
# dtype: int64

# %%
#mean of tmdb_popularity column
round(merged_data['tmdb_popularity'].mean(),2)
# Out:
# np.float64(10.32)

# %%
#replacing null values in tmdb_popularity column with mean
merged_data['tmdb_popularity'].fillna(round(merged_data['tmdb_popularity'].mean(),2), inplace=True)

# %% [markdown]
# The tmdn_score is same as imdb_score so perform mean on tmdb_score

# %%
#mean of tmdb_score
round(merged_data['tmdb_score'].mean(),1)
# Out:
# np.float64(6.0)

# %%
#replacing null values in tmdb_score column with mean
merged_data['tmdb_score'].fillna(round(merged_data['tmdb_score'].mean(),1), inplace=True)

# %%
merged_data.isnull().sum()
# Out:
# id                          0
# title                       0
# type                        0
# description                 0
# release_year                0
# age_certification           0
# runtime                     0
# genres                      0
# production_countries        0
# seasons                     0
# imdb_id                     0
# imdb_score                  0
# imdb_votes                  0
# tmdb_popularity             0
# tmdb_score                  0
# person_id                   0
# name                        0
# character               14989
# role                        0
# dtype: int64

# %% [markdown]
# There are missing values in the character column, this indicates the name of the character played by the actor, but as it is missing a value let's replace them by 'unknown'

# %%
#replacing the missing values in character column by unknown
merged_data['character'].fillna('unknown', inplace=True)

# %%
merged_data.isnull().sum()
# Out:
# id                      0
# title                   0
# type                    0
# description             0
# release_year            0
# age_certification       0
# runtime                 0
# genres                  0
# production_countries    0
# seasons                 0
# imdb_id                 0
# imdb_score              0
# imdb_votes              0
# tmdb_popularity         0
# tmdb_score              0
# person_id               0
# name                    0
# character               0
# role                    0
# dtype: int64

# %%
merged_data.shape
# Out:
# (119022, 19)

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
merged_data.duplicated().sum()
# Out:
# np.int64(168)

# %% [markdown]
# We have 168 duplicate values, let's drop these values

# %%
#dropping the duplicate values from the dataset
merged_data.drop_duplicates(inplace=True)

# %%
merged_data.duplicated().sum()
# Out:
# np.int64(0)

# %%
merged_data.dtypes
# Out:
# id                       object
# title                    object
# type                     object
# description              object
# release_year              int64
# age_certification        object
# runtime                   int64
# genres                   object
# production_countries     object
# seasons                 float64
# imdb_id                  object
# imdb_score              float64
# imdb_votes              float64
# tmdb_popularity         float64
# tmdb_score              float64
# person_id                 int64
# name                     object
# character                object
# role                     object
# dtype: object

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# The dataset contains information about movies and TV shows available on Amazon Prime Video. It includes attributes such as title, type (Movie or TV Show), release year, age certification, genre, duration, country of origin, IMDb_score, and number of IMDb_votes. It had about 124347 rows and 19 columns after merging the two datasets. The data includes both numerical and categorical attributes. Some of the attributes had missing values so I ensured that missing values were either handled or filled appropriately (e.g., setting IMDb_votes to 0 for unrated titles), duplicates were removed, and all column formats were standardized. After all the cleaning we have 118854 rows and 19 columns, now we can perform our analysis on this data.

# %% [markdown]
# ## **3. Understanding Your Variables**

# %%
# Dataset Columns
merged_data.columns
# Out:
# Index(['id', 'title', 'type', 'description', 'release_year',
#        'age_certification', 'runtime', 'genres', 'production_countries',
#        'seasons', 'imdb_id', 'imdb_score', 'imdb_votes', 'tmdb_popularity',
#        'tmdb_score', 'person_id', 'name', 'character', 'role'],
#       dtype='object')

# %%
# Dataset Describe
merged_data.describe()
# Out:
#         release_year        runtime        seasons     imdb_score  \
# count  118854.000000  118854.000000  118854.000000  118854.000000
# mean     1995.694592      96.054453       0.153466       5.968600
# std        28.010517      29.798646       1.006917       1.238145
# min      1912.000000       1.000000       0.000000       1.100000
# 25%      1980.000000      83.000000       0.000000       5.200000
# 50%      2009.000000      94.000000       0.000000       6.000000
# 75%      2017.000000     109.000000       0.000000       6.800000
# max      2022.000000     328.000000      49.000000       9.900000
#
#          imdb_votes  tmdb_popularity     tmdb_score     person_id
# count  1.188540e+05    118854.000000  118854.000000  1.188540e+05
# mean   2.312887e+04        10.334860       5.997704  3.976869e+05
# std    8.819975e+04        40.786345       1.252196  5.549632e+05
# min    0.000000e+00         0.000164       0.800000  1.000000e+00
# ...

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
merged_data.nunique()
# Out:
# id                       8262
# title                    8165
# type                        2
# description              8254
# release_year              110
# age_certification          11
# runtime                   200
# genres                   1961
# production_countries      472
# seasons                    31
# imdb_id                  8262
# imdb_score                 86
# imdb_votes               3624
# tmdb_popularity          5105
# tmdb_score                 87
# person_id               77333
# name                    76639
# character               68819
# role                        2
# dtype: int64

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# As we can see the dataset is clean and ready for further analysis. The manipulations performed on given data are as follows,
#
#
# 1. **Data Loading and Merging:** Two datasets, titles.csv and credits.csv were loaded and merged based on the common attribute 'id'.
# 2. **Handling Missing Values:**
#   *   Null values in the 'description' and 'imdb_id' columns were dropped.
#   *   Null values in 'age_certification' were replaced with the mode values.
#   *   Null values in 'seasons', 'imdb_votes', and 'character' were replaced with 0, 0, and 'unknown' respectively.
#   *   Null values in 'imdb_score', 'tmdb_popularity', and 'tmdb_score' were replaced with their respective mean values.
# 3. **Handling Duplicates:** Duplicate rows identified and removed from the dataset.

# %% [markdown]
# ## **4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables**

# %% [markdown]
# Data Visualization is the graphical representation of information and data. By using visual elements like charts, graphs, and maps, data visualization tools provide an accessible way to see and understand trends, outliers, and patterns in data.

# %% [markdown]
# ## **Univariate Analysis**

# %%
merged_data
# Out:
#                id              title   type  \
# 0         ts20945  The Three Stooges   SHOW
# 1         ts20945  The Three Stooges   SHOW
# 2         ts20945  The Three Stooges   SHOW
# 3         tm19248        The General  MOVIE
# 4         tm19248        The General  MOVIE
# ...           ...                ...    ...
# 124342  tm1054116           Baikunth  MOVIE
# 124343  tm1054116           Baikunth  MOVIE
# 124344  tm1054116           Baikunth  MOVIE
# 124345  tm1054116           Baikunth  MOVIE
# 124346  tm1054116           Baikunth  MOVIE
#
#                                               description  release_year  \
# 0       The Three Stooges were an American vaudeville ...          1934
# 1       The Three Stooges were an American vaudeville ...          1934
# 2       The Three Stooges were an American vaudeville ...          1934
# 3       During America’s Civil War, Union spies steal ...          1926
# ...

# %% [markdown]
# ### **BOX PLOT**

# %% [markdown]
# ##### **Box plot of imdb_score**

# %% [markdown]
# Box plots are plotted to visualize the distribution, spread of data and to identify outliers in data

# %%
# Box plot of imdb_score
plt.figure(figsize=(10, 6))
sns.boxplot(y='imdb_score', data=merged_data)
plt.title('Box Plot of imdb_score')
plt.show()

# %% [markdown]
# ##### Insights

# %% [markdown]
# *   The horizontal line within the box represents the median of imdb_score. This tells us the rating for movies and TV Shows on Amazon Prime.
# *   Points plotted beyond the lower and upper whiskers are considered as outliers. These represents the movies or TV Shows with high or low imdb_score.

# %% [markdown]
# ##### **Box Plot of runtime**

# %%
# Box plot of runtime
plt.figure(figsize=(10, 6))
sns.boxplot(x='runtime', data=merged_data)
plt.title('Box Plot of runtime')
plt.show()

# %% [markdown]
# ##### **Insights**

# %% [markdown]
# *   Box plot of runtime helps to understand the distribution, typical runtime, spread , and outliers in the runtime data of movies and TV shows on Amazon Prime.
# *   The horizontal line inside the box represents the median runtime, which is around 90 minutes.
# *   Points plotted outside the whiskers are considered outliers. These are movies or TV shows with short or long runtimes compared to the majority of the content.

# %% [markdown]
# ### **HISTOGRAM**

# %% [markdown]
# Histograms represents the distribution of numerical variable. They provide a visual way to see the shape of data's distribution.

# %% [markdown]
# ##### **Histogram of release_year**

# %%
# Histogram of release_year
plt.figure(figsize=(10, 6))
sns.histplot(merged_data['release_year'], bins=20, color = 'blue', kde=True)
plt.title('Histogram of release_year\n')
plt.show()

# %% [markdown]
# ##### **Insights**

# %% [markdown]
# *   The histogram of the release year column shows the distribution of movies and TV shows across different release years.
# *   A large amount of content on Amazon Prime is released recently that is in last decade. The distribution is skewed towards left.
# *   We can see an overall increasing trend in the number of movies or TV shows released over the years. This suggests that Amazon Prime Video's content library has been expanding.

# %% [markdown]
# ##### **Histogram of Seasons**

# %%
# Histogram of Seasons
plt.figure(figsize=(10, 6))
sns.histplot(data = merged_data, x = 'seasons', bins=20)
plt.title('Histogram of Seasons\n')
plt.show()

# %% [markdown]
# ##### **Insights**

# %% [markdown]
# *   The histogram shows peak at 1 as number of seasons are only applicable to TV shows, Movies don't have seasons.
# *   Most of the TV shows on Amazon prime have 1 to 3 seasons. This suggests that many TV shows don't continue for more number of seasons.

# %% [markdown]
# ## **BAR PLOT/COUNT PLOT**

# %% [markdown]
# A bar plot is a type of chart that presents categorical data with rectangular bars with heights or lengths proportional to the values that they represent.

# %% [markdown]
# ##### **Bar plot of Type(Movie or TV Show)**

# %%
val = merged_data.type.value_counts()
val
# Out:
# type
# MOVIE    111454
# SHOW       7400
# Name: count, dtype: int64

# %%
# Bar plot of Type
plt.figure(figsize=(10, 6))
sns.barplot(x=val.index, y=val)
plt.title('Bar Plot of Type(Movie or TV Show\n')
plt.show()

# %% [markdown]
# ##### **Insights**

# %% [markdown]
# *   The bar for "Movie" is significantly higher than the bar for "SHOWS", indicating that there are more number of movies than TV shows available on platform.
# *   Amazon prime is focusing on Movies over TV shows, this could be because viewers choosing movies over shows.
# *   The above information could be valuable for content creators as they can produce, release movies on this platform.

# %% [markdown]
# #### **Bar plot of age_certification**

# %%
val1 = merged_data.age_certification.value_counts()
val1
# Out:
# age_certification
# R        88755
# PG-13    12302
# PG        9437
# G         3674
# TV-MA     1712
# TV-14     1478
# TV-PG      494
# TV-Y7      353
# TV-Y       293
# TV-G       240
# NC-17      116
# Name: count, dtype: int64

# %%
# Bar plot of age_certification
plt.figure(figsize=(10, 6))
sns.barplot(x=val1.index, y=val1, color = 'red')
plt.title('Bar Plot of age_certification\n')
plt.show()

# %% [markdown]
# ##### **Insights**

# %% [markdown]
# *   Age cerification 'R' means person under age 17 requires accompanying parent or adult guardian. There are highest number of movies with 'R' certification.
# *   Movies or TV shows with PG-13 rating are at 2nd position these movies may contain material that parents might find inappropriate for younger children, typically those under 13 years old.

# %% [markdown]
# #### **Bar plot of genres**

# %%
genre_counts = merged_data['genres'].value_counts()
val2 = genre_counts[genre_counts>1500]
val2
# Out:
# genres
# ['drama']                         8639
# ['comedy']                        5014
# ['drama', 'romance']              2501
# ['horror']                        2050
# ['documentation']                 2027
# ['drama', 'comedy']               1937
# ['comedy', 'drama']               1935
# ['romance', 'comedy']             1622
# ['comedy', 'romance']             1605
# ['thriller', 'crime', 'drama']    1513
# Name: count, dtype: int64

# %%
# Bar plot of genres
plt.figure(figsize=(10, 6))
sns.barplot(y=val2.index, x=val2, color = 'green')
plt.title('Bar Plot of genres\n')
plt.show()

# %% [markdown]
# ##### **Insights**

# %% [markdown]
# *   The genre with tallest bars "drama","comedy" are the most common genre on Amazon prime. This also reflects the viewers preferences.
# *   Although some generes dominate but there are variety of genres available on the platform. This indicates that Amazon prime offers content with diverse taste and preferences.
# *   The genre distribution can be useful for recommending content to the viewers.

# %% [markdown]
# ## **Bivariate Analysis**

# %% [markdown]
# #### **SCATTER PLOT**

# %% [markdown]
# A scatter plot is a type of data visualization that uses dots to represent the values of two numerical variables. Scatter plots are used to observe relationships between variables.

# %%
# Scatter plot of imdb_vote and imdb_scores
plt.figure(figsize=(10, 6))
sns.scatterplot(x='imdb_votes', y='imdb_score', data=merged_data)
plt.title('Scatter Plot of imdb_vote and imdb_scores\n')
plt.show()

# %% [markdown]
# ##### **Insights**

# %% [markdown]
# *   Positive Correlation: The scatter plot shows a positive correlation between imdb_votes and imdb_score. This means that as the number of votes for a title increases, its IMDb score also tends to increase.
# *   Positive correlation suggests that titles with more votes are popular and recieves higher ratings.

# %% [markdown]
# #### **LINE PLOT**

# %% [markdown]
# Line plot connects data points with a line to show trends over time across continuous variable

# %% [markdown]
# #### **Line plot of runtime v/s release_year**

# %%
# Line plot of runtime v/s release_year
plt.figure(figsize=(10, 6))
sns.lineplot(x='release_year', y='runtime', data=merged_data)
plt.title('Line plot of runtime v/s release_year\n')
plt.show()

# %% [markdown]
# ##### **Insights**

# %% [markdown]
# *   There is slight downward trend in average runtime of movies and TV shows over the years. This indicates that Movies and Tv shows are getting shorter.
# *   In the earlier years movies and TV shows tended to have longer runtimes, but in more recent years the average runtime has decreased.
# *   This decrease in runtime is because of shorter attention span of viewers, production cost.

# %% [markdown]
# #### **Line plot of seasons v/s release_year**

# %%
# Line plot of seasons v/s release_year
plt.figure(figsize=(10, 6))
sns.lineplot(x='release_year', y='seasons', data=merged_data)
plt.title('Line plot of seasons v/s release_year\n')
plt.show()

# %% [markdown]
# ##### **Insights**

# %% [markdown]
# *   There is upward trend in number of seasons for TV shows over the years. This shows that TV shows are becoming longer, with more seasons.
# *   The overall upward trend suggests that viewers are willing to invest their time to watch more seasons of a perticular TV show.

# %% [markdown]
# ### **PIE CHART**

# %% [markdown]
# Pie chart is used to visualize the propositions of different categories within a dataset. It's circular statistical graph where each slice of the pie represents a category and the size of the slice is proportional to the category's contribution to the overall data.

# %% [markdown]
# #### **Pie chart of type(Movie or TV Show)**

# %%
# Pie chart of type(Movie or TV Show)
plt.figure(figsize=(10, 6))
merged_data['type'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title('Pie chart of type(Movie or TV Show)\n')
plt.show()

# %% [markdown]
# ##### **Insights**

# %% [markdown]
# *   The large size for 'Movies' indicates that Amazon prime primarily focuses on offering a vast collection of movies to it's viewer.
# *   This information is enough to understand Amazon prime attracts viewers who enjoy watching Movies rather than TV shows.

# %% [markdown]
# ## **Multivariate Analysis**

# %% [markdown]
# #### **PAIR PLOT**

# %% [markdown]
# Pair plots visualize the pairwise relationship between variables. It includes scatter plots for relationships and histogram or density plots for individual distributions.

# %%
# Pair Plot visualization code
plt.figure(figsize=(10, 6))
sns.pairplot(merged_data)
plt.show()

# %% [markdown]
# #### **HEAT MAP**

# %% [markdown]
# A heat map uses color intensities to represent the strength of relationships(correlation) between numeric values in a dataset.

# %%
num_cols = merged_data.select_dtypes(include=np.number).columns
num_cols
# Out:
# Index(['release_year', 'runtime', 'seasons', 'imdb_score', 'imdb_votes',
#        'tmdb_popularity', 'tmdb_score', 'person_id'],
#       dtype='object')

# %%
# visualization of heat maps
plt.figure(figsize=(10, 6))
sns.heatmap(merged_data[num_cols].corr(), annot=True, cmap='coolwarm')
plt.title('Heat Map\n')
plt.show()

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# This Exploratory Data Analysis (EDA) of the Amazon Prime Video dataset has provided valuable insights into the platform's content, trends, and user preferences.
# *   Amazon Prime Video hosts a significantly larger number of movies compared to TV shows.
# *   Drama and Comedy are the most common genres, reflecting mainstream viewer preferences.
# *   The platform offers a diverse range of genres, catering to a wide variety of audience tastes.
# *   Movie runtimes have slightly decreased over the years, indicating a trend toward shorter films.
# *   TV shows have increased in the number of seasons, suggesting rising engagement with series content.
# *   Older titles generally receive higher IMDb and TMDb ratings compared to newer ones, possibly due to nostalgia or established fan bases.
# *   The United States is the leading content producer, followed by India and the United Kingdom, showing strong contributions from these countries.
#
# ##### Overall, this EDA has successfully uncovered patterns and trends in the Amazon Prime Video dataset, offering valuable information for content creators, platform strategists, and viewers alike. Further analysis and deeper dives into specific genres, regions, or content types could provide even richer insights for future decision-making.
